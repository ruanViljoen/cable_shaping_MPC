# %%
import numpy as np
import matplotlib.pyplot as plt
from plotting_functions import plot_time_series, plot_box_whisker, get_number_of_successful_trials, plot_calc_time_box_and_whiskers, plot_tracking_error_box_and_whiskers

# %% [markdown]
# Tracking error

# %%
idx_lower = 0
idx_upper = 10

# %%
plot_time_series("MPC", [idx_lower, idx_upper], "fps_error", save_fig_flag=True)

# %%
plot_time_series("baseline", [idx_lower, idx_upper], "fps_error", save_fig_flag=True)

# %%
plot_tracking_error_box_and_whiskers(
    [
        "mpc_horizon_1",
        "mpc_horizon_3",
        "mpc_horizon_5",
        "mpc_horizon_7",
        "mpc_horizon_10",
        "mpc_horizon_12",
        "mpc_horizon_15",
        "mpc_horizon_20"
    ], 
    [
        "1",
        "3",
        "5",
        "7",
        "10",
        "12",
        "15",
        "20"
    ], 
    [idx_lower, idx_upper], log_scale=False, save_fig_flag=True
)

# %%
# plot_calc_time_box_and_whiskers(["rk4", "lmpc_rk4", "lmpc_euler", "zoo_mpc", "mpc_ruan"], ["nmpc (rk4)", "lmpc (rk4)", "lmpc (euler)", "zoo mpc", "ruan_mpc"], [idx_lower, idx_upper], log_scale=True)
plot_calc_time_box_and_whiskers(["baseline","test"], ["baseline", "proposed method"], [idx_lower, idx_upper], log_scale=True, save_fig_flag=True)

# %%
get_number_of_successful_trials(
    [
        "gain1", 
        "gain1.5",
        "gain2",
    ],
    [
        "gain1", 
        "gain1.5",
        "gain2",
    ],
    [idx_lower, idx_upper],
    0.015
)

# %%
get_number_of_successful_trials("mpc_5_with_online_learning_with_limits_0.1_constrained_window_5", [idx_lower, idx_upper], 0.01, start_time=10)

# %%
plot_box_whisker(
    [
        "gain1", 
        "mpc_5_with_online_learning_with_limits_0.1_constrained_window_5",
        "baseline_elim",
        "mpc_5_with_online_learning_with_limits_0.5_constrained_window_5"
    ],
    [
        "baseline",
        "MPC (v_max = 0.1)",
        "baseline_elim",
        "MPC (v_max = 0.5)",
    ],
    [idx_lower, idx_upper], 
    "fps_error"
)

# %%
plot_time_series("mpc_ruan_0.1", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_ruan_0.1_12", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("lmpc_rk4", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("lmpc_euler", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("test", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_ruan", [idx_lower, idx_upper], "fps_error")

# %%
idx_lower = 34
idx_upper = 35

# %%
plot_time_series("zoo_mpc", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("test", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_ruan_0.1_20", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_ruan_0.1_15", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_ruan_0.1_5", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("test2", [idx_lower, idx_upper], "fps_error")

# %%
# plot_time_series("rk4_tolerant", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("baseline_elim", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("original_10points", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("baseline_elim_10points", [idx_lower, idx_upper], "fps_error")

# %%
# plot_time_series("nmpc", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("RTI", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("acados", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_linearized", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("lmpc_8points", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("lmpc_8points_gain2", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("nmpc_8points", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_temp", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("nmpc_online_learning", [idx_lower, idx_upper], "fps_error")

# %%
idx_lower = 0
idx_upper = 15

# %%
plot_time_series("gain1", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("baseline_elim", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_temp", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("RTI", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_complex", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_linearized", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("nmpc", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("nmpc_online_learning", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_linearized_fixed_weights", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_temp", [idx_lower, idx_upper], "fps_error")

# %%
plot_time_series("mpc_5_with_online_learning_with_limits_0.5_constrained_window_5", [idx_lower, idx_upper], "fps_error")

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/baseline_casadi/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.1/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.5_constrained_window_20/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.5_constrained_window_5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/baseline_elim/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/baseline_with_online_learning_with_reset/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/baseline_vlim_0.5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.5_temp/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_no_limits/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(idx):
    alpha = 0.2
    if i in [34, 79]:
        alpha = 1
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_5/state_"+str(i)+".npy")
    plt.plot([np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]], alpha=alpha)

# %%
task_error_all = []

for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/gain1/state_"+str(i)+".npy")
    desired_positions = state[:,-30:]
    positions = state[:,1:31]
    error = np.linalg.norm((positions - desired_positions), axis=1)
    if i not in [14,32,34,60,73,79]:
        task_error_all.append( np.mean(error[-10 : -1]))

ave_task_error_all = np.mean(np.array(task_error_all))
print(ave_task_error_all)

# %%
task_error_all = []

for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_5/state_"+str(i)+".npy")
    desired_positions = state[:,-30:]
    positions = state[:,1:31]
    error = np.linalg.norm((positions - desired_positions), axis=1)

    task_error_all.append( np.mean(error[-10 : -1]))

ave_task_error_all = np.mean(np.array(task_error_all))
print(ave_task_error_all)

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/gain1.5/state_"+str(i)+".npy")
    plt.plot([np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/gain2/state_"+str(i)+".npy")
    plt.plot([np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])
    
# save the data
np.save("task_error_all.npy", task_error_all)

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('tracking error [m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_20/state_"+str(i)+".npy")
    plt.plot([np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])
    # plt.plot(x,[np.linalg.norm(x) for x in state[:,1:31] - state[:,-30:]])

# %% [markdown]
# Feature point velocities

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('Feature point velocities[m]')
# for i in range(100):
i = 0
state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_limits/state_"+str(i)+".npy")
x = [i*0.1 for i in range(state.shape[0])]
plt.plot(x,[x for x in state[:,45:75]])
pass

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('Feature point velocities[m]')
# for i in range(100):
i = 0
state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_limits/state_"+str(i)+".npy")
x = [i*0.1 for i in range(state.shape[0])]
plt.plot(x,[x for x in state[:,45:75]])
pass

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('Feature point velocities[m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/gain1/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,45:75]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('Feature point velocities[m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,45:75]])

# %% [markdown]
# Robot control velocities

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('right hand linear velocity [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/baseline_elim/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,75:78]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('right hand linear velocity [m]')
for i in range(idx):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.1/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,75:78]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('right hand linear velocity [m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/mpc_5_with_online_learning_with_limits_0.5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,75:78]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('right hand linear velocity [m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,75:78]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('right hand angular velocity [m]')
for i in range(11):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/fixed_ee/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,78:81]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('right hand angular velocity [m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_20/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,78:81]])

# %%
plt.figure(figsize=(10,5))
plt.xlabel('time [s]')
plt.ylabel('right hand angular velocity [m]')
for i in range(100):
    state = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_5/state_"+str(i)+".npy")
    x = [i*0.1 for i in range(state.shape[0])]
    plt.plot(x,[np.linalg.norm(x) for x in state[:,78:81]])

# %% [markdown]
# Bar graphs

# %%
plt.figure(figsize=(30,5))

errors_MPC = []
errors_gain1 = []
errors_gain1_5 = []
errors_gain2 = []
for i in range(100):
    state_MPC = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/MPC_5/state_"+str(i)+".npy")
    state_gain1 = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/gain1/state_"+str(i)+".npy")
    state_gain1_5 = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/gain1.5/state_"+str(i)+".npy")
    state_gain2 = np.load("/home/ruan/Sandbox/shape_control_DLO_2/results/gain2/state_"+str(i)+".npy")
    errors_MPC += [np.sum([np.linalg.norm(x) for x in state_MPC[:,1:31] - state_MPC[:,-30:]])]
    errors_gain1 += [np.sum([np.linalg.norm(x) for x in state_gain1[:,1:31] - state_gain1[:,-30:]])]
    errors_gain1_5 += [np.sum([np.linalg.norm(x) for x in state_gain1_5[:,1:31] - state_gain1_5[:,-30:]])]
    errors_gain2 += [np.sum([np.linalg.norm(x) for x in state_gain2[:,1:31] - state_gain2[:,-30:]])]



bar_width = 0.2

bar_positions1 = np.arange(len(errors_MPC))+0.1
bar_positions2 = np.arange(len(errors_MPC))+0.3
bar_positions3 = np.arange(len(errors_MPC))+0.5
bar_positions4 = np.arange(len(errors_MPC))+0.7

plt.bar(bar_positions1, errors_gain1, bar_width, label='Gain=1')
# plt.bar(bar_positions2, errors_gain1_5, bar_width, label='Gain=1.5')
# plt.bar(bar_positions3, errors_gain2, bar_width, label='Gain=2')
plt.bar(bar_positions2, errors_MPC, bar_width, label='MPC')
plt.xlim(0,100)
# plt.set_xticks(bar_positions1 + bar_width / 2)
# ax.set_xticklabels(x_labels)

plt.legend()

plt.show() # 34, 35, 79

# %%
plt.figure(figsize=(30,5))
bar_width = 0.5

delta_erros = np.array(errors_gain1) - np.array(errors_MPC)

bar_positions = np.arange(len(errors_MPC))+0.25
# bar_positions2 = np.arange(len(errors_MPC))+0.3
# bar_positions3 = np.arange(len(errors_MPC))+0.5
# bar_positions4 = np.arange(len(errors_MPC))+0.7

plt.bar(bar_positions, delta_erros, bar_width, label='Mpc error - Gain=1 error')
plt.xlim(0,100)
# plt.set_xticks(bar_positions1 + bar_width / 2)
# ax.set_xticklabels(x_labels)

plt.legend()

plt.show()

# %% [markdown]
# Plot bar graph of delta errors

# %% [markdown]
# Box-and-whiskers plot

# %%
plt.boxplot([errors_MPC, errors_gain1, errors_gain1_5, errors_gain2])
pass
