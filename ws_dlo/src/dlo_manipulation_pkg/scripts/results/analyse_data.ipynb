# %%
import numpy as np
import matplotlib.pyplot as plt
from plotting_functions import plot_time_series, plot_calc_time_box_and_whiskers, plot_tracking_error_box_and_whiskers

# %% [markdown]
# Tracking error

# %%
idx_lower = 0
idx_upper = 100

# %%
plot_calc_time_box_and_whiskers(["MPC","baseline"], ["MPC", "baseline"], [idx_lower, idx_upper], log_scale=True, save_fig_flag=True)

# %%
# plot_calc_time_box_and_whiskers(
#     ["mpc_horizon_1", "mpc_horizon_3", "mpc_horizon_5", "mpc_horizon_7", "mpc_horizon_10", "mpc_horizon_12", "mpc_horizon_15", "mpc_horizon_20"],
#     ["1", "3", "5", "7", "10", "12", "15", "20"],
#     [idx_lower, idx_upper], log_scale=True, save_fig_flag=True)

# %%
plot_time_series("baseline", [idx_lower, idx_upper], save_fig_flag=False)

# %%
plot_time_series("MPC", [idx_lower, idx_upper], save_fig_flag=True)

# %%
plot_tracking_error_box_and_whiskers(
    ["mpc_horizon_1", "mpc_horizon_3", "mpc_horizon_5", "mpc_horizon_7", "mpc_horizon_10", "mpc_horizon_12", "mpc_horizon_15", "mpc_horizon_20"],
    ["1", "3", "5", "7", "10", "12", "15", "20"],
    [idx_lower, idx_upper],
    save_fig_flag=True
)
